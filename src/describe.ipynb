# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = "../data/training_traces/traces_plan_r1.json"
df = pd.read_json(file)
print(len(df))
# Out:
# 261

# %%
# Plot the distribution of total_length for failed entries
plt.figure(figsize=(10, 6))
sns.histplot(df['total_length'], bins=30, kde=True)
plt.title('Distribution of Total Length')
plt.xlabel('Total Length')
plt.ylabel('Frequency')
plt.show()

# %%
import cplex
import os

# %%
prob = cplex.Cplex("/home/uto/cplex/cplex/bin/x86-64_linux/")
# Out:
# CPLEX Error  1424: Invalid filetype.
# ---------------------------------------------------------------------------
# CplexSolverError                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 prob = cplex.Cplex("/home/uto/cplex/cplex/bin/x86-64_linux/cplex")
#
# File ~/miniconda3/envs/cplex/lib/python3.10/site-packages/cplex/__init__.py:809, in Cplex.__init__(self, *args)
#     807 elif isinstance(args[0], str):
#     808     self._lp = _proc.createprob(self._env._e, args[0])
# --> 809     _proc.readcopyprob(self._env._e, self._lp, args[0])
#     810 else:
#     811     raise TypeError("invalid argument: {0}".format(args[0]))
#
# File ~/miniconda3/envs/cplex/lib/python3.10/site-packages/cplex/_internal/_procedural.py:688, in readcopyprob(env, lp, filename, filetype)
#     686 else:
#     687     status = CR.CPXXreadcopyprob(env, lp, filename, filetype)
# --> 688 check_status(env, status)
#
# ...
